# %%
import pandas as pd

# %%
transfer_data = pd.read_csv('transfer_data.csv')
disposal_data = pd.read_csv('disposal_data.csv')
transaction_data = pd.read_csv('transaction_data.csv')

# %%
transfer_data.head()
# Out:
#                    Facility Name  \
# 0        Foster Transfer Station
# 1     Koonwarra Transfer Station
# 2    Korumburra Transfer Station
# 3  Mirboo North Transfer Station
# 4     Venus Bay Transfer Station
#
#                                     Facility address   Longitude   Latitude
# 0  South Gippsland Highway, Foster, 3960, Victori...  146.210413 -38.649272
# 1               Koonwarra, 3954, Victoria, Australia  145.927735 -38.556792
# 2  Silkstone Road, Korumburra, 3950, Victoria, Au...  145.835205 -38.446692
# 3  Railway Road, Mirboo North, 3871, Victoria, Au...  146.172041 -38.401094
# 4  Cnr Canterbury Road and No 3 Beach Road, Venus...  145.809972 -38.696300

# %%
disposal_data.head()
# Out:
#     Disposal Facility   Longitude   Latitude  \
# 0  Koonwarra Landfill  145.922786 -38.560592
# 1             Norstar  145.195330 -38.023900
# 2                Visy  145.204880 -38.014900
# 3        GT Recycling  144.431460 -38.160460
# 4                 MRI  144.950830 -37.649610
#
#                            Disposal Facility Address
# 0               Koonwarra, 3954, Victoria, Australia
# 1  160-162 Colchester Rd, Bayswater North, 3153, ...
# 2  708 Princes Hwy, Springvale, 3171, Victoria, A...
# 3  100 Point Henry Rd, Moolap, 3221, Victoria, Au...
# 4  1789-1791 Sydney Rd, Campbellfield, 3061, Vict...

# %%
transaction_data.head()
# Out:
#    DBNO  TRANSNO               Facility NAME           DATETIMEIN  WEIGHTNETT  \
# 0     2    39539  Venus Bay Transfer Station  2017-09-01 09:55:37         0.0
# 1     2    39549  Venus Bay Transfer Station  2017-09-01 11:44:17         0.0
# 2     2    39551  Venus Bay Transfer Station  2017-09-02 09:44:01         0.0
# 3     2    39563  Venus Bay Transfer Station  2017-09-02 11:15:18         0.0
# 4     2    39566  Venus Bay Transfer Station  2017-09-02 11:27:54         0.0
#
#   ITEM GROUP NAME        ITEM NAME INNOUTUT  ITEM QTY  Volume m3  \
# 0  Domestic Waste  01) Bag (<120L)       IN         1      0.075
# 1  Domestic Waste  01) Bag (<120L)       IN         1      0.075
# 2  Domestic Waste  01) Bag (<120L)       IN         1      0.075
# 3  Domestic Waste  01) Bag (<120L)       IN         1      0.075
# 4  Domestic Waste  01) Bag (<120L)       IN         1      0.075
#
#    Density factor (t/m3)  kg per item  tot tonnes Disposal Facility
# ...

# %%
transaction_data.loc[~transaction_data['Disposal Facility'].isna()]
# Out:
#       DBNO  TRANSNO                  Facility NAME           DATETIMEIN  \
# 4831     1     4445     Koonwarra Transfer Station  2017-09-19 11:00:26
# 4832     1     4446  Mirboo North Transfer Station  2017-09-19 11:01:36
# 4833     1     4447     Venus Bay Transfer Station  2017-09-19 11:03:45
# 4834     1     4453     Koonwarra Transfer Station  2017-09-26 11:09:08
# 4835     1     4454   Walkerville Transfer Station  2017-09-26 11:10:01
# 4836     1     4455     Koonwarra Transfer Station  2017-09-28 11:10:53
# 4837     1     4456        Foster Transfer Station  2017-09-28 11:11:47
# 4838     1     4439     Koonwarra Transfer Station  2017-09-01 10:48:54
# 4839     1     4457     Koonwarra Transfer Station  2017-09-30 11:12:51
# 4840     1     4407     Koonwarra Transfer Station  2017-09-01 14:54:04
# 4841     1     4408    Korumburra Transfer Station  2017-09-04 14:55:12
# 4842     1     4409     Koonwarra Transfer Station  2017-09-04 14:56:08
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://sv_user:sv_password@localhost/sv')
connection = engine.connect()
transfer_data.to_sql('transfer_station', con=connection, index=False)
connection.close()
# Out:
# c:\users\vikrant\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py:2130: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b351b794fb12> in <module>
#       1 engine = create_engine('mysql+mysqlconnector://sv_user:sv_password@localhost/sv')
#       2 connection = engine.connect()
# ----> 3 transfer_data.to_sql('transfer_station', con=connection, index=False)
#       4 connection.close()
#
# c:\users\vikrant\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
# ...
